# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import emoji
import re

# %%
#create copy하세요
# 전 copy가 원본이라 생각

# %%
os.getcwd()
# Out:
# 'c:\\Users\\asia\\Desktop\\ai_project\\zigzag'

# %%
#데이터 불러오기
dataset_path = Path("dataset")
item = "슬리브리스"
item_dir = Path(os.path.join(dataset_path,item))
og_dir =  Path(os.path.join(dataset_path,item + ' copy'))
def get_file_paths(directory):
    files_path = []
    if os.path.exists(directory):
        files_path = [str(file) for file in directory.rglob('*')]
        files_path = sorted(files_path, key=lambda x: int(re.search(r'p(\d+)', x).group(1)) if re.search(r'p(\d+)', x) else float('inf'))
    else:
        print(f"directory not found")
        return
    return files_path
item_paths = get_file_paths(item_dir)
og_paths = get_file_paths(og_dir)

# %%
# Helper Fucn
def get_file(path):
    return pd.read_csv(path,on_bad_lines="skip")

def save_file(df, path):
    df.to_csv(path, index=False)

# %%
p1 = get_file(item_paths[0])
p2 = get_file(item_paths[1])
p3 =  get_file(item_paths[2])

# %%
p2
# Out:
#             아이디  리뷰어 등급     작성 날짜                             옵션1   옵션2  \
# 0          나애옷장   상위 1%  25.01.09        [TT037] 보들쫀쫀 끈나시_화이트(골지)  FREE
# 1          무민민무   상위 5%  24.07.09            [TT037] 보들쫀쫀 끈나시_단가라  FREE
# 2        5145**     NaN  24.06.24        [TT037] 보들쫀쫀 끈나시_화이트(골지)  FREE
# 3      k7RVT5WW     NaN  24.06.09            [TT037] 보들쫀쫀 끈나시_단가라  FREE
# 4    돈은없지만옷은사고파   상위 5%  24.11.27      [TT037] 보들쫀쫀 끈나시_단가라(★롱기장)  FREE
# ..          ...     ...       ...                             ...   ...
# 995    VG1t9uG0  상위 20%  24.04.29      [TT037] 보들쫀쫀 끈나시_단가라(★롱기장)  FREE
# 996    SKcBoMJO     NaN  24.04.27        [TT037] 보들쫀쫀 끈나시_그레이(골지)  FREE
# 997    2zX0wkcw     NaN  24.04.26      [TT037] 보들쫀쫀 끈나시_단가라(★롱기장)  FREE
# 998    2zX0wkcw     NaN  24.04.26  [TT037] 보들쫀쫀 끈나시_화이트(골지)(★롱기장)  FREE
# 999    L1Zqqt1g   상위 5%  24.04.26      [TT037] 보들쫀쫀 끈나시_단가라(★롱기장)  FREE
#
#      상품 사이즈      퀄리티        색감      키   몸무게    사이즈  \
# 0    정사이즈예요  아주 만족해요  화면과 비슷해요  155cm  46kg    NaN
# 1    정사이즈예요  아주 만족해요  화면과 비슷해요  165cm  53kg  상의 55
# 2    정사이즈예요  아주 만족해요  화면과 비슷해요  160cm  54kg  상의 66
# 3       작아요  아주 만족해요  화면과 비슷해요  158cm  75kg  상의 77
# 4       작아요  아주 만족해요  화면과 비슷해요  165cm  55kg  상의 55
# ..      ...      ...       ...    ...   ...    ...
# 995  정사이즈예요  아주 만족해요  화면과 비슷해요  168cm  54kg  상의 55
# 996  정사이즈예요    보통이에요  화면과 비슷해요  171cm  53kg  상의 66
# 997  정사이즈예요  아주 만족해요  화면과 비슷해요    NaN   NaN    NaN
# 998  정사이즈예요  아주 만족해요  화면과 비슷해요    NaN   NaN    NaN
# 999  정사이즈예요    보통이에요  화면과 비슷해요  164cm  52kg  상의 55
#
#                                                   리뷰내용
# 0    ☁️ 믿고 사는 데일리템, 조이조이 보들쫀쫀 골지 나시\n\n☁️ 2024. 12....
# 1    생각보다 도톰했어요~! 그리고 안에 이너 사야한다는걸 깜빡해서 고냥 끈 풀고 입었는...
# 2    스파오에서 골지 나시를 사서 입어보고 빳빳한 골지에 반해서 더 사려고 했는데 품절이...
# 3    길다는 후기를보고 샀는디..가슴있으신 분들은 더 짧아집니다...생각보다 쫀쫀하고 거...
# 4    상체 발달형에다가 상체가 짧아서 허리선을 가리면 너무 뚱뚱해보이고 부해보이고 너무 ...
# ..                                                 ...
# 995  탄탄하고 쫀쫀하니 좋아요! 유교걸인데 가디건 안에 받쳐입기에 딱 좋네요! 길이는 고...
# 996  골지는 롱 사이즈가 없어서 기본 사이즈로 구매했습니다 길이가 딱 맞아서 괜찮긴 한데...
# 997  연베이지 바탕에 블랙 스트라이프가 깔끔하구요 쇄골 아래까지 올라와서 노출 신경 안 ...
# 998  화이트 색상만 두 개를 구입했을 정도로 활용도도 높고 기장도 너무나 마음에 듭니다 ...
# 999  롱하기 잘한것같아요.\n롱도 생각보다 많이 안길고 골반정도 길이감이라서 딱 좋고 스...
#
# [1000 rows x 12 columns]

# %%
og_p2 = get_file(og_paths[0])
og_p2
# Out:
#           아이디  리뷰어 등급     작성 날짜          옵션1       옵션2  상품 사이즈      퀄리티  \
# 0         NaN     NaN       NaN          NaN       NaN     NaN      NaN
# 1      nxxhee    탑리뷰어  24.11.27   (롱ver)아이보리  one size  정사이즈예요    보통이에요
# 2    u2QwGGfF     NaN  24.07.07           블랙         L  정사이즈예요  아주 만족해요
# 3    WMKwL2mc     NaN  24.06.26    (롱롱ver)블랙  one size  정사이즈예요  아주 만족해요
# 4    HCi3CFRP     NaN  25.01.09  (기모롱ver)베이지  one size  정사이즈예요  아주 만족해요
# ..        ...     ...       ...          ...       ...     ...      ...
# 995  XaE4oG2g  상위 30%  24.10.17         아이보리  one size  정사이즈예요    보통이에요
# 996  jliPGve6  상위 15%  24.10.10         아이보리  one size  정사이즈예요    보통이에요
# 997  orDbsTqv  상위 30%  24.10.02    (롱ver)그레이  one size  정사이즈예요  아주 만족해요
# 998  zjqdiPmt     NaN  24.09.14     (롱ver)크림  one size  정사이즈예요  아주 만족해요
# 999   0814***     NaN  24.09.09     (롱ver)블랙  one size     작아요     별로예요
#
#            색감      키   몸무게    사이즈  \
# 0         NaN    NaN   NaN    NaN
# 1    화면과 비슷해요  164cm  56kg  상의 55
# 2    화면과 비슷해요  163cm  58kg  상의 66
# 3    화면과 비슷해요  156cm  50kg  상의 55
# 4    화면과 비슷해요  167cm  52kg  상의 55
# ..        ...    ...   ...    ...
# 995  화면과 비슷해요  156cm  48kg  상의 55
# 996  화면과 비슷해요  165cm  52kg  상의 55
# 997  화면과 비슷해요  164cm  51kg  상의 44
# 998  화면과 비슷해요  159cm  55kg  상의 55
# 999  화면과 비슷해요    NaN   NaN    NaN
#
#                                                   리뷰내용
# 0                                                  NaN
# 1    제 인생은 캡나시 알기 전과 후로 나뉩니다,,\nZZIZZI가 작아서 그런지 모르겠...
# 2    L사이즈가 있길래 직잭배송으로 구매했더니 아침에 바로 입어볼 수 있었네요ㅎㅎ L사이...
# 3    이가격에, 이 옵션 수에, 이런 총알배송??? 만족도 최상. 당장 사십시오. 저는 ...
# 4    가격대비 품질이 너무 좋네요. \n셔링들어간 건 처음입는데 몸라인이 정말 예뻐보여요...
# ..                                                 ...
# 995  75B 가슴이 조금 쳐진 스타일입니다🙈\n단독으로 입는 게 맞겠죠?\n절대 가슴 지...
# 996  받았을 때 좀 작아보였는데\n막상 입으니까 속옷 안입고 요거만 입어도 핏도 괜찮고\...
# 997  끈이 얇아서 몇번 입고 나면 뜯어진다는 타사 제품들도 많은데 여기꺼는 아무리 입고 ...
# 998  후기가 좋아서 구매하려보니 다 품절이더라고요ㅠㅠ\n재고 있는거로 시켰는데 너무 예뻐...
# 999  냄새 심각합니다\n지그재그 첫 이용해봤는데 많이 실망이네요\n뭐 중국 사이트에서 구...
#
# [1000 rows x 12 columns]

# %% [markdown]
# 데이터프레임에서 특정 열(키, 몸무게, 사이즈)에 대해 단위(unit)가 없는 값이나 잘못된 값을 찾는 작업

# %% [markdown]
# # check_wrong_data 잘못된 행 찾는 함수

# %%
# 수동적으로 해야할 것들
# Check for 키, 몸무게, 사이즈 rows where the unit is missing or invalid

unit_dict = {'키': 'cm', '몸무게': 'kg', '사이즈': '상의'}

def check_wrong_data(df):
    invalid_rows_list = []
    
    for col in unit_dict.keys():
        expected_unit = unit_dict[col]
        invalid_rows = df[df[col].apply(lambda x: pd.notna(x) and isinstance(x, str) and expected_unit not in x)]
        invalid_rows_list.append(invalid_rows)
    
    # Combine all invalid rows and drop duplicates
    consolidated_invalid_rows = pd.concat(invalid_rows_list).drop_duplicates()
    
    return consolidated_invalid_rows

def check_wrong_items(option):
    if option == "og":
        paths = og_paths
    elif option == "replace":
        paths = item_paths
    else:
        return (f"no option exists")
    combined_df = pd.DataFrame()
    
    for path in paths:
        if path.endswith('.txt'):
            continue
        df = get_file(path)
        wrong_df = check_wrong_data(df)
        combined_df = pd.concat([combined_df, wrong_df], ignore_index=True)
    return combined_df

# %%
before = check_wrong_items("og")
before
# Out:
#            아이디  리뷰어 등급     작성 날짜                  옵션1         옵션2   상품 사이즈  \
# 0     i2tTKXN4     NaN  24.08.02             (롱ver)핑크    one size      작아요
# 1     사고시푼거다사자  상위 15%  24.09.24                소프트라임         NaN   정사이즈예요
# 2     utCEz3xL     NaN  24.09.11                 아이보리         NaN      작아요
# 3     8cFlBIbb     NaN  24.09.12                소프트라임         NaN   정사이즈예요
# 4     8cFlBIbb     NaN  24.09.12                 아이보리         NaN   정사이즈예요
# 5           고흐     NaN  24.09.20                   블랙         NaN   정사이즈예요
# 6     eyiSCGXQ     NaN  24.06.21  찰랑 베이직(M사이즈_하프6장세트)         NaN  생각보다 커요
# 7     SsZjtci5     NaN  24.08.22             L(66~77)           롱  생각보다 커요
# 8     BrZ8ExHx     NaN  24.06.28                블랙(b)        선택안함   정사이즈예요
# 9     esZOa4YR     NaN  24.09.14                 아이보리        FREE   정사이즈예요
# 10  ksg_******  상위 15%  24.09.05                   블랙        FREE   정사이즈예요
# 11         복숭아  상위 10%  24.09.12                  2매입    스킨 XL 1매   정사이즈예요
# 12    qEUgRZoF     NaN  24.11.05                  2매입   블랙 XXL 1매   정사이즈예요
# 13    9Dh1fHTu     NaN  24.10.18                  2매입  아이보리 XL 1매   정사이즈예요
# 14    5Qn40Q3n     NaN  24.10.12                   카키    one size   정사이즈예요
# 15    tmZUYjMl  상위 15%  24.08.08                   소라    one size   정사이즈예요
# 16    tmZUYjMl  상위 15%  24.08.08                   카키    one size   정사이즈예요
# 17    1ejNdneY     NaN  25.01.09                   카키    one size   정사이즈예요
# 18       dangg    탑리뷰어  24.10.22                   XL        아이보리   정사이즈예요
# 19       dangg    탑리뷰어  24.10.10                   XL          블랙   정사이즈예요
# 20    T1U7vYqL     NaN  24.08.01                단품 1매        아이보리   정사이즈예요
#
#         퀄리티         색감      키    몸무게  사이즈  \
# 0     보통이에요   화면과 비슷해요  165cm  상의 55  NaN
# 1   아주 만족해요   화면과 비슷해요   69kg  상의 77  NaN
# 2     보통이에요   화면과 비슷해요   65kg    NaN  NaN
# 3     보통이에요   화면과 비슷해요   47kg    NaN  NaN
# 4     보통이에요   화면과 비슷해요   47kg    NaN  NaN
# 5   아주 만족해요   화면과 비슷해요  163cm  상의 55  NaN
# 6   아주 만족해요   화면과 비슷해요  165cm  상의 55  NaN
# 7   아주 만족해요   화면과 비슷해요  상의 66    NaN  NaN
# 8     보통이에요   화면과 비슷해요  161cm  상의 55  NaN
# 9   아주 만족해요   화면과 비슷해요  159cm  상의 44  NaN
# 10    보통이에요   화면과 비슷해요  163cm  상의 66  NaN
# 11    보통이에요   화면과 비슷해요  158cm  상의 55  NaN
# 12  아주 만족해요   화면과 비슷해요  160cm  상의 77  NaN
# 13    보통이에요   화면과 비슷해요  169cm  상의 55  NaN
# 14  아주 만족해요   화면과 비슷해요  상의 66    NaN  NaN
# 15  아주 만족해요   화면과 비슷해요  158cm  상의 44  NaN
# 16  아주 만족해요   화면과 비슷해요  158cm  상의 44  NaN
# 17  아주 만족해요  화면보다 어두워요  165cm  상의 66  NaN
# 18  아주 만족해요   화면과 비슷해요  상의 66    NaN  NaN
# 19  아주 만족해요   화면과 비슷해요  상의 66    NaN  NaN
# 20  아주 만족해요   화면과 비슷해요  상의 66    NaN  NaN
#
#                                                  리뷰내용
# 0   편하고 색 이뻐요! 내장캡은 제가 사용하기엔 뭔가 좀 갖다 붙여놓은 기분? 가슴 전...
# 1   부유방 커버 잘되고 핏도 컬러도 너무 예뻐요ㅠㅠ 색깔 다 소장하고 싶은 옷입니당.....
# 2   입던 거라 구매! 블랙 샀는데 노브라 가능해서 구매했어요 걸치는 셔츠 안에 입을 나...
# 3                       배송빠르고 좋아요 재질도 좋고 맘에들어요 또주문할게요
# 4                       배송빠르고 좋아요 재질도 좋고 맘에들어요 또주문할게요
# 5   쫀쫀하다기보다는 탄탄하긴 한데요!\n군살은 딱 잡아줘서 좋았습니다~ 내년엔 밝은 색...
# 6   한개 실밥이.. 이렇게 나와있는거 빼고 6장에 이가격이면 굉장히 만족스러워요~~ 소...
# 7   보기보다 퀄리티 있어요 근데 패드넣는 부분이 작다고 해야하나 그래서 패드 안넣고 입...
# 8   흰색을 시킨다는걸 검정색으로 잘 못 시켰는데 예뻐서 그냥 흰색 추가 구매 했습니다....
# 9   나시처럼 쭉쭉 늘어나는 재질을 생각했는데 제대로 꽉 잡아줘서 엄청 예쁘게 떨어져요!...
# 10  나시 끈이 생각보다 더 약해보이긴했는데 .. 입었을 때 스판이 쫀쫀해서 좋았고 핏도...
# 11  패드가 원단 겉에 안 비치는 색으로 되어 있어서 좋아요\n엄청 부들하고 쫀쫀합니다 ...
# 12  캡도 내장되어있으니 너무 편하고 빨래해도 보풀 잘 안일나고 굉장히 편해요 생각보다 ...
# 13                       너무 편해서 이거 말고 다른 이너제품에는 손이안가요
# 14  여행갈때입으려고 샀어요! 이너로 입으니 이쁘고 만족스러웠습니다~! 살빼서 모델분처럼...
# 15  색감도 탁한 하늘이고 목라인 짱짱하고 부유방 커버도 되고 여러모로 만족합니다\n재구...
# 16  목라인 짱짱하고 부유방 잘 가려줘서 좋은거 같아요\n놀러가서 잘 입을께요\n재구매 ...
# 17  태국 여행가서 입으려고 카키 구매해봤는데 너무 예뻐서 아이보리 추가로 구매했어요👍👍...
# 18  검정색 구매했다가 너무너무 만족해서 흰색도 구매했어요.\n일단 추워지면서 크롭이 아...
# 19  이전에 마른5 리치 모달 나시탑을 구매해서 착용하고 있었는데 크롭 기장이여서 쌀쌀해...
# 20  평소 m사이즈 입는데 딱 맞아요. 소재 부드럽고 편하구요 짱짱하게 스판기 있어서 좋...

# %%
# 위 두개를 돌려보고 난 뒤
# 긴소매 기준 , unit 기준으로 대체해도 괜찮다고 판단
def move_data(df):
    for index, row in df.iterrows():
        for col in unit_dict.keys():
            expected_unit = unit_dict[col]
            if pd.notna(row[col]) and expected_unit not in str(row[col]):
                # Find the correct column for this value
                for target_col, target_unit in unit_dict.items():
                    if target_unit in str(row[col]):
                        # Move the value to the correct column
                        df.at[index, target_col] = row[col]
                        df.at[index, col] = None  # Clear the original value
                        break
    return df

def move_all_data(option):
    if option == "og":
        paths = og_paths
    elif option == "replace":
        paths = item_paths
    else:
        return (f"no option exists")
    
    for path in item_paths:
        if path.endswith('.txt'):
            continue
        df = get_file(path)
        updated_df = move_data(df) # 여기서 실제 inplace
        save_file(updated_df, path)

# %%
# For Sanity Check
move_all_data("replace") #og 가 아닌 것에 inplace
after = check_wrong_items("replace")
after
# Out:
# Empty DataFrame
# Columns: [아이디, 리뷰어 등급, 작성 날짜, 옵션1, 옵션2, 상품 사이즈, 퀄리티, 색감, 키, 몸무게, 사이즈, 리뷰내용]
# Index: []

# %%
# Check if any rows are NaN
def remove_all_NaN_row(df):
    df= df.dropna(how='all')
    return df
    
# Remove units and spaces 
def drop_units(df):
    df["키"] = df["키"].str.replace(r"\s*cm\s*","",regex = True) 
    df["몸무게"] = df["몸무게"].str.replace(r"\s*kg\s*","",regex = True)
    df["사이즈"] = df["사이즈"].str.replace(r"\s*상의\s*","",regex = True)
    return df


# # Change it to float
# def change_to_int(df,col):
#     if len(col) > 1:
#         for c in col:
#             #<NA>로 되버려 pandas._libs.missing.NAType
#             df[c] = pd.to_numeric(df[c], errors="coerce").astype("Int64")
#     else:
#         df[col] = pd.to_numeric(df[col], errors="coerce").astype("Int64")
#     return df


# Remove emoji
def remove_emoji(df):
    def remove_emojis(text):
        return emoji.replace_emoji(text, replace='')  
        df["리뷰"] =df["리뷰"].apply(remove_emojis)
    return df

# %%
p2.describe()
# Out:
#              아이디 리뷰어 등급     작성 날짜                   옵션1   옵션2  상품 사이즈  \
# count       1000    412      1000                  1000  1000    1000
# unique       861      8       398                    29     8       3
# top     vXqN8CrE  상위 5%  24.05.26  [TT037] 보들쫀쫀 끈나시_단가라  FREE  정사이즈예요
# freq           4     85        11                   248   723     916
#
#             퀄리티        색감      키   몸무게    사이즈  \
# count      1000      1000    909   906    897
# unique        3         3     31    42      7
# top     아주 만족해요  화면과 비슷해요  160cm  50kg  상의 55
# freq        644       985    106    95    486
#
#                                                      리뷰내용
# count                                                1000
# unique                                                927
# top     색깔과 디자인 별로 구매했습니다. \n일단 롱 기장이 있어서 좋았어요!\n나시가 짧...
# freq                                                    4

# %%
p2["색감"].value_counts()
# Out:
# 색감
# 화면과 비슷해요     985
# 화면보다 어두워요     10
# 화면보다 밝아요       5
# Name: count, dtype: int64

# %%
p2["옵션1"].value_counts()
# Out:
# 옵션1
# [TT037] 보들쫀쫀 끈나시_단가라              248
# [TT037] 보들쫀쫀 끈나시_단가라(★롱기장)        119
# 단가라                                85
# [TT037] 보들쫀쫀 끈나시_화이트(골지)           80
# [TT037] 보들쫀쫀 끈나시_그레이(골지)           78
# [TT037] 보들쫀쫀 끈나시_블랙(골지)            49
# 단가라(★롱기장)                          45
# [TT037] 보들쫀쫀 끈나시_화이트(골지)(★롱기장)     44
# [TT037] 보들쫀쫀 끈나시_블랙(골지)(★롱기장)      37
# [TT036] 보들쫀쫀 끈나시_화이트(민자)           34
# 화이트(골지)                            34
# 블랙(골지)                             23
# 그레이(골지)                            22
# [TT037] 보들쫀쫀 끈나시_화이트(민자)(★롱기장)     15
# 블랙(골지)(★롱기장)                       15
# [TT036] 보들쫀쫀 끈나시_블랙(민자)            13
# 화이트(골지)(★롱기장)                      13
# [TT037] 보들쫀쫀 끈나시_블랙(민자)(★롱기장)      10
# 화이트(민자)                             9
# 블랙(민자)                              8
# [TT036] 보들쫀쫀 끈나시_핑크(민자)             6
# 화이트(민자)(★롱기장)                       3
# 블랙(민자)(★롱기장)                        2
# 스킨(골지)                              2
# [TT036] 보들쫀쫀 끈나시_베이지(민자)            2
# 핑크(민자)                              1
# White (Golji)                       1
# [TT037] 보들쫀쫀 끈나시_스킨(골지)             1
# 베이지(민자)                             1
# Name: count, dtype: int64

# %%
p2["옵션2"].value_counts()
# Out:
# 옵션2
# FREE                        723
# Free                        264
# [TT037] 보들쫀쫀 끈나시_블랙(골지)       7
# [TT037] 보들쫀쫀 끈나시_그레이(골지)      2
# [TT037] 보들쫀쫀 끈나시_화이트(골지)      1
# (1개만 구매!)                     1
# [TT036] 보들쫀쫀 끈나시_화이트(민자)      1
# [TT036] 보들쫀쫀 끈나시_블랙(민자)       1
# Name: count, dtype: int64

# %%
p2[p2["옵션2"]=='[TT036] 보들쫀쫀 끈나시_블랙(민자)']
# Out:
#           아이디 리뷰어 등급     작성 날짜                       옵션1  \
# 754  ximjeyoW    NaN  22.07.09  [TT037] 보들쫀쫀 끈나시_화이트(골지)
#
#                          옵션2 상품 사이즈    퀄리티        색감      키   몸무게    사이즈  \
# 754  [TT036] 보들쫀쫀 끈나시_블랙(민자)    작아요  보통이에요  화면과 비슷해요  167cm  52kg  상의 55
#
#                                                   리뷰내용
# 754  셔츠 안에 잘 받쳐 입고 있어요! 셔츠 단추 두개 푸는 거 좋아하는데 사이즈가 몸에...

# %%
p2["몸무게"].value_counts()
# Out:
# 몸무게
# 50kg        95
# 55kg        66
# 48kg        64
# 53kg        63
# 52kg        58
# 54kg        57
# 58kg        54
# 49kg        38
# 60kg        37
# 51kg        34
# 57kg        31
# 47kg        29
# 59kg        27
# 46kg        26
# 56kg        25
# 43kg        20
# 62kg        19
# 45kg        18
# 63kg        17
# 70kg        15
# 65kg        15
# 61kg        12
# 67kg        11
# 64kg        10
# 42kg         9
# 68kg         8
# 40kg         8
# 30kg 이하      6
# 44kg         5
# 41kg         4
# 66kg         4
# 69kg         4
# 38kg         3
# 72kg         3
# 39kg         2
# 75kg         2
# 130kg 이상     2
# 71kg         1
# 73kg         1
# 80kg         1
# 77kg         1
# 37kg         1
# Name: count, dtype: int64

# %%
p1["키"].value_counts()
# Out:
# 키
# 160cm       111
# 158cm        88
# 163cm        83
# 164cm        74
# 159cm        65
# 162cm        53
# 168cm        51
# 165cm        49
# 161cm        48
# 166cm        46
# 156cm        40
# 157cm        37
# 167cm        33
# 155cm        31
# 153cm        26
# 170cm        20
# 169cm        20
# 154cm        18
# 172cm        10
# 171cm         8
# 173cm         6
# 152cm         6
# 150cm         6
# 151cm         4
# 175cm         3
# 148cm         1
# 130cm 이하      1
# 174cm         1
# Name: count, dtype: int64

# %%
p1["상품 사이즈"].value_counts()

# %%
p1["작성 날짜"]
# Out:
# 0           NaN
# 1      24.11.27
# 2      24.07.07
# 3      24.06.26
# 4      25.01.09
#          ...
# 995    24.10.17
# 996    24.10.10
# 997    24.10.02
# 998    24.09.14
# 999    24.09.09
# Name: 작성 날짜, Length: 1000, dtype: object

# %%
p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   아이디     1000 non-null   object
#  1   리뷰어 등급  180 non-null    object
#  2   작성 날짜   1000 non-null   object
#  3   옵션1     1000 non-null   object
#  4   옵션2     1000 non-null   object
#  5   상품 사이즈  1000 non-null   object
#  6   퀄리티     1000 non-null   object
#  7   색감      999 non-null    object
#  8   키       903 non-null    object
#  9   몸무게     903 non-null    object
#  10  사이즈     903 non-null    object
#  11  리뷰내용    1000 non-null   object
# dtypes: object(12)
# memory usage: 93.9+ KB
